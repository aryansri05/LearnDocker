# %% [markdown]
# <a href="https://colab.research.google.com/github/aryansri05/LearnDocker/blob/master/R3_4DGS_Automation_Runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Install system dependencies
# !apt-get update
# !apt-get install -y libply-dev
# !pip install ninja
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2108310838.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 # Install system dependencies
#       5 get_ipython().system('apt-get update')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...

# %%
# Clone the repository and its submodules
# !git clone https://github.com/hustvl/4DGaussians --recursive
# %cd 4DGaussians

# Install basic requirements
# !pip install -r requirements.txt
# !pip install ninja  # Ninja makes the C++/CUDA compilation much faster
# Out:
# Cloning into '4DGaussians'...
# remote: Enumerating objects: 2625, done.
# remote: Total 2625 (delta 0), reused 0 (delta 0), pack-reused 2625 (from 1)
# Receiving objects: 100% (2625/2625), 66.30 MiB | 38.23 MiB/s, done.
# Resolving deltas: 100% (1216/1216), done.
# Submodule 'submodules/depth-diff-gaussian-rasterization' (https://github.com/ingra14m/depth-diff-gaussian-rasterization) registered for path 'submodules/depth-diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/4DGaussians/submodules/depth-diff-gaussian-rasterization'...
# remote: Enumerating objects: 287, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 287 (delta 150), reused 149 (delta 149), pack-reused 120 (from 1)
# Receiving objects: 100% (287/287), 83.13 KiB | 4.62 MiB/s, done.
# ...

# %%
# 1. Install requirements but ignore the version strictness
# %cd /content/4DGaussians
# !sed -i 's/torch==1.13.1//g' requirements.txt  # This removes the old torch requirement from the file
# !pip install -r requirements.txt

# 2. Now manually install the submodules (the "Heavy Lifting")
# This might take 5-10 minutes.
# !pip install -e submodules/depth-diff-gaussian-rasterization
# !pip install -e submodules/simple-knn
# Out:
# /content/4DGaussians
# ERROR: Ignored the following yanked versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.1 (from versions: 0.17.0, 0.17.1, 0.17.2, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.20.0, 0.20.1, 0.21.0, 0.22.0, 0.22.1, 0.23.0, 0.24.0, 0.24.1, 0.25.0)
# ERROR: No matching distribution found for torchvision==0.14.1
# Obtaining file:///content/4DGaussians/submodules/depth-diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for diff_gaussian_rasterization
# ...
# Obtaining file:///content/4DGaussians/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for simple_knn
#     error: subprocess-exited-with-error
#
#     × python setup.py develop did not run successfully.
#     │ exit code: 1
#     ╰─> See above for output.
#
# ...

# %%
# 1. Clear the outdated version pins from requirements.txt
# %cd /content/4DGaussians
# !sed -i 's/torchvision==0.14.1//g' requirements.txt
# !sed -i 's/torchaudio==0.13.1//g' requirements.txt

# 2. Install modern requirements (Colab already has torch 2.x, so we skip it)
# !pip install plyfile tqdm scipy
# !pip install open3d  # You'll need this for the Week 1 visualization task

# 3. Fix and Re-install submodules
# We use --no-build-isolation to ensure it uses the GPU-enabled torch already in Colab
# !pip install -e submodules/depth-diff-gaussian-rasterization --no-build-isolation
# !pip install -e submodules/simple-knn --no-build-isolation
# Out:
# /content/4DGaussians
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 67.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...
# Obtaining file:///content/4DGaussians/submodules/depth-diff-gaussian-rasterization
# ...

# %%
import os

# 1. Go back into the project folder
# %cd /content/4DGaussians

# 2. Correctly install simple-knn using the full path
# !pip install ./submodules/simple-knn --no-build-isolation
# Out:
# [Errno 2] No such file or directory: '/content/4DGaussians'
# /content
# ERROR: Invalid requirement: './submodules/simple-knn': Expected package name at the start of dependency specifier
#     ./submodules/simple-knn
#     ^
# Hint: It looks like a path. File './submodules/simple-knn' does not exist.

# %%
import os

# 1. Force move to /content
# %cd /content

# 2. Clone ONLY if the folder doesn't exist
if not os.path.exists('4DGaussians'):
    # !git clone https://github.com/hustvl/4DGaussians --recursive

# 3. Enter the folder
# %cd 4DGaussians

# 4. Final attempt at simple-knn with the absolute internal path
# !pip install ./submodules/simple-knn --no-build-isolation
# Out:
# /content
# Cloning into '4DGaussians'...
# remote: Enumerating objects: 2625, done.
# remote: Total 2625 (delta 0), reused 0 (delta 0), pack-reused 2625 (from 1)
# Receiving objects: 100% (2625/2625), 66.30 MiB | 14.83 MiB/s, done.
# Resolving deltas: 100% (1216/1216), done.
# Submodule 'submodules/depth-diff-gaussian-rasterization' (https://github.com/ingra14m/depth-diff-gaussian-rasterization) registered for path 'submodules/depth-diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/4DGaussians/submodules/depth-diff-gaussian-rasterization'...
# remote: Enumerating objects: 287, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 287 (delta 150), reused 149 (delta 149), pack-reused 120 (from 1)
# Receiving objects: 100% (287/287), 83.13 KiB | 1.70 MiB/s, done.
# ...

# %%
# %cd /content/4DGaussians/submodules/simple-knn

# Manually trigger the build and installation
# !python setup.py install

# Move back to the main directory
# %cd /content/4DGaussians
# Out:
# /content/4DGaussians/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# %cd /content/4DGaussians/submodules/simple-knn

# Inject the missing header into the CUDA file
# !sed -i '1i #include <float.h>' simple_knn.cu

# Re-run the manual installation
# !python setup.py install

# Move back to the main directory
# %cd /content/4DGaussians
# Out:
# /content/4DGaussians/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
import sys
import os

# Add the compiled modules to the path
sys.path.append(os.path.abspath("/content/4DGaussians"))

try:
    import diff_gaussian_rasterization
    import simple_knn
    print("✅ ENGINES ONLINE. You are ready to reconstruct!")
except Exception as e:
    print(f"❌ Setup error: {e}")
# Out:
# ❌ Setup error: No module named 'diff_gaussian_rasterization'

# %%
import sys
import os

# Manually find and add the submodules to Python's search path
# %cd /content/4DGaussians
sys.path.append(os.path.abspath("submodules/depth-diff-gaussian-rasterization"))
sys.path.append(os.path.abspath("submodules/simple-knn"))

# Try the import again
try:
    import diff_gaussian_rasterization
    import simple_knn
    print("✅ SUCCESS: The engines are officially linked!")
except ImportError:
    # If it still fails, we force-install one last time using 'pip' with the absolute path
    # !pip install ./submodules/depth-diff-gaussian-rasterization
    # !pip install ./submodules/simple-knn
    import diff_gaussian_rasterization
    import simple_knn
    print("✅ SUCCESS: Forced installation complete!")
# Out:
# /content/4DGaussians
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Processing ./submodules/depth-diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3801941 sha256=299d7fb6a6e44a68aa51e33522605854a577ff0dfd34175a93e27f0d64b82704
#   Stored in directory: /root/.cache/pip/wheels/9b/f0/79/7050876d7058176b835697bafb337203a561a35f85dbd429b5
# Successfully built diff_gaussian_rasterization
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys

# 1. Setup the Repository
# %cd /content
if not os.path.exists('4DGaussians'):
    # !git clone https://github.com/hustvl/4DGaussians --recursive
# %cd 4DGaussians

# 2. Fix Requirements & Install Basic Tools
# !sed -i 's/torchvision==0.14.1//g' requirements.txt
# !sed -i 's/torchaudio==0.13.1//g' requirements.txt
# !sed -i 's/torch==1.13.1//g' requirements.txt
# !pip install -r requirements.txt
# !pip install ninja plyfile tqdm scipy open3d

# 3. Build & Install Submodules (The "Engine")
# We apply the FLT_MAX patch to simple-knn before building
# !sed -i '1i #include <float.h>' submodules/simple-knn/simple_knn.cu
# !pip install -e submodules/depth-diff-gaussian-rasterization --no-build-isolation
# !pip install submodules/simple-knn --no-build-isolation

# 4. Inject Paths so Python finds the new modules
sys.path.append(os.path.abspath("submodules/depth-diff-gaussian-rasterization"))
sys.path.append(os.path.abspath("submodules/simple-knn"))

print("✅ ENVIRONMENT CONFIGURED. You are ready for the watchdog script.")
# Out:
# /content
# /content/4DGaussians
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 45.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 97.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 98.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.6 MB/s eta 0:00:00
# ...
